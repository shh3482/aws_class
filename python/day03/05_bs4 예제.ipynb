# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.example.com"
res = requests.get(url)

# HTML 소스를 넘겨받아 BeautifulSoup 객체 생성
soup = BeautifulSoup(res.text, 'lxml')

# 원하는 요소 찾기 (태그명으로 찾기)
title_tag = soup.title
body_tag = soup.body

print(title_tag.text) # 태그 안의 텍스트만 추출
