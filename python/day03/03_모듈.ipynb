# %%
# 모듈 전체 가져오기
import math

print(math.pi)
print(math.sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
# 일부만 가져오기
from math import pi, sqrt

print(pi)
print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
# 별칭
import math as m

print(m.pi)
print(m.sqrt(16))

# %%
import my_module as my

my.print_hello()
my.train()
# Out:
# Hello Python!!
# 학습 중 ....
